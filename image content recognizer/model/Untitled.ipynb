# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import json
import en_core_web_sm
import spacy

# %%
pip list
# Out:
# Package            Version     Editable project location
# ------------------ ----------- -------------------------------------------------------------------------
# aniso8601          9.0.1
# annotated-types    0.6.0
# asttokens          2.2.1
# backcall           0.2.0
# bcrypt             4.0.1
# beautifulsoup4     4.11.1
# blinker            1.6.2
# blis               0.7.11
# catalogue          2.0.10
# certifi            2023.5.7
# charset-normalizer 3.1.0
# click              8.1.3
# cloudpathlib       0.16.0
# colorama           0.4.6
# comm               0.1.3
# confection         0.1.3
# contourpy          1.0.7
# cycler             0.11.0
# cymem              2.0.8
# debugpy            1.6.7
# decorator          5.1.1
# dnspython          2.3.0
# email-validator    1.3.1
# en-core-web-sm     2.2.0
# executing          1.2.0
# ffmpeg             1.4
# fields             5.0.0
# Flask              2.2.2
# Flask-Bcrypt       1.0.1
# Flask-Login        0.6.2
# Flask-RESTful      0.3.10
# Flask-SQLAlchemy   3.0.2
# Flask-WTF          1.1.1
# fonttools          4.38.0
# greenlet           2.0.1
# gunicorn           20.1.0
# idna               3.4
# ipykernel          6.24.0
# ipython            8.14.0
# itsdangerous       2.1.2
# jedi               0.18.2
# Jinja2             3.1.2
# joblib             1.2.0
# jupyter_client     8.3.0
# jupyter_core       5.3.1
# keras              2.11.0
# kiwisolver         1.4.4
# langcodes          3.3.0
# lxml               4.9.2
# MarkupSafe         2.1.2
# matplotlib         3.6.3
# matplotlib-inline  0.1.6
# murmurhash         1.0.10
# nest-asyncio       1.5.6
# numpy              1.24.1
# packaging          23.0
# pandas             1.5.3
# pandas-datareader  0.10.0
# parso              0.8.3
# pickleshare        0.7.5
# Pillow             9.4.0
# pip                23.1.2
# pip-system-certs   4.0
# platformdirs       3.9.1
# preshed            3.0.9
# prompt-toolkit     3.0.38
# psutil             5.9.5
# pure-eval          0.2.2
# pycolab            1.0         C:\Users\liyak\Downloads\random\ai-safety-hackathon\reversibility\pycolab
# pydantic           2.5.1
# pydantic_core      2.14.3
# Pygments           2.15.1
# pyparsing          3.0.9
# pytesseract        0.3.10
# python-dateutil    2.8.2
# pytz               2022.7.1
# pywin32            306
# pyzmq              25.1.0
# requests           2.31.0
# scikit-learn       1.2.0
# scipy              1.10.0
# seaborn            0.12.2
# setuptools         65.5.0
# six                1.16.0
# smart-open         6.4.0
# soupsieve          2.3.2.post1
# spacy              3.7.2
# spacy-legacy       3.0.12
# spacy-loggers      1.0.5
# SQLAlchemy         1.4.46
# srsly              2.4.8
# stack-data         0.6.2
# stats              0.1.2a0
# thinc              8.2.1
# threadpoolctl      3.1.0
# tornado            6.3.2
# tqdm               4.66.1
# traitlets          5.9.0
# typer              0.9.0
# typing_extensions  4.6.3
# tzdata             2023.3
# urllib3            2.0.3
# wasabi             1.1.2
# wcwidth            0.2.6
# weasel             0.3.4
# Werkzeug           2.2.2
# wrapt              1.16.0
# WTForms            3.0.1
# xgboost            1.7.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pytesseract as tess
import PIL.Image

# %%
tess.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
text = tess.image_to_string(PIL.Image.open("C:\\Python Learning\\Python Learning\\Current Python learning\\image content recognizer\\pages\\static\\uploads\\Path-finding.png"))

# %%
print(text)
# Out:
# A* Path with Bezier Curve Smoothing
#
# --- Bezier Curve (Smoothed Path)
#
# (0, S 2, 7 3, 4, 7: oe ne tet)
#
# | |
# , 6 47, 6)
#
# | |
# 47, 5)
#
# | |
# 5 7, 4)
#
# | |
# 47, 3)
#
# | |
# 2 47, 2)
#
# | |
# , H—7, 1)
#
# i i i
# (0, 0} —-A, 0} 22, 0} +3, 0} 4, 0} 5, 0} 46, 0} 47, 0)

# %%
nlp = spacy.load('en_core_web_sm')
# nlp = en_core_web_sm.load()

def preprocess_text(text):
    doc = nlp(text)
    tokens = [token.text.lower() for token in doc if not token.is_stop and not token.is_punct]
    return tokens
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Python Learning\Python Learning\Current Python learning\image content recognizer\model\Untitled.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Python%20Learning/Python%20Learning/Current%20Python%20learning/image%20content%20recognizer/model/Untitled.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> nlp = spacy.load('en_core_web_sm')
#       <a href='vscode-notebook-cell:/c%3A/Python%20Learning/Python%20Learning/Current%20Python%20learning/image%20content%20recognizer/model/Untitled.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> # nlp = en_core_web_sm.load()
#       <a href='vscode-notebook-cell:/c%3A/Python%20Learning/Python%20Learning/Current%20Python%20learning/image%20content%20recognizer/model/Untitled.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> def preprocess_text(text):
#
# File c:\Python\Lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File c:\Python\Lib\site-packages\spacy\util.py:472, in load_model(name, vocab, disable, enable, exclude, config)
#     470 if name in OLD_MODEL_SHORTCUTS:
#     471     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2
#      -----------------                        5.2/12.0 MB 2.6 MB/s eta 0:00:03
#      -----------------                        5.3/12.0 MB 2.6 MB/s eta 0:00:03
#      ------------------                       5.5/12.0 MB 2.6 MB/s eta 0:00:03
#      -------------------                      5.8/12.0 MB 2.7 MB/s eta 0:00:03
#      -------------------                      6.0/12.0 MB 2.7 MB/s eta 0:00:03
#      --------------------                     6.2/12.0 MB 2.7 MB/s eta 0:00:03
#      ---------------------                    6.5/12.0 MB 2.8 MB/s eta 0:00:02
#      ----------------------                   6.8/12.0 MB 2.9 MB/s eta 0:00:02
#      -----------------------                  7.2/12.0 MB 3.0 MB/s eta 0:00:02
#      ------------------------                 7.3/12.0 MB 3.0 MB/s eta 0:00:02
#      -------------------------                7.8/12.0 MB 3.1 MB/s eta 0:00:02
#      ---------------------------              8.2/12.0 MB 3.2 MB/s eta 0:00:02
#      ----------------------------             8.5/12.0 MB 3.3 MB/s eta 0:00:02
#      -----------------------------            8.9/12.0 MB 3.4 MB/s eta 0:00:01
#      ------------------------------           9.3/12.0 MB 3.4 MB/s eta 0:00:01
#      -------------------------------          9.6/12.0 MB 3.5 MB/s eta 0:00:01
#      ---------------------------------        10.0/12.0 MB 3.6 MB/s eta 0:00:01
#      ---------------------------------        10.2/12.0 MB 3.6 MB/s eta 0:00:01
#      ----------------------------------       10.5/12.0 MB 3.9 MB/s eta 0:00:01
#      ----------------------------------       10.5/12.0 MB 3.9 MB/s eta 0:00:01
#      -----------------------------------      10.6/12.0 MB 3.9 MB/s eta 0:00:01
#      ------------------------------------     11.0/12.0 MB 4.0 MB/s eta 0:00:01
#      -------------------------------------    11.3/12.0 MB 4.2 MB/s eta 0:00:01
#      --------------------------------------   11.7/12.0 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------------  11.8/12.0 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------------  12.0/12.0 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------------- 12.0/12.0 MB 4.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: spacy>=2.2.0 in c:\python\lib\site-packages (from en-core-web-sm==2.2.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.5.1)
# Requirement already satisfied: jinja2 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\python\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.24.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\python\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.2.0->en-core-web-sm==2.2.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.3 in c:\python\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.2.0->en-core-web-sm==2.2.0) (2.14.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\python\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.2.0->en-core-web-sm==2.2.0) (4.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\python\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy>=2.2.0->en-core-web-sm==2.2.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\python\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy>=2.2.0->en-core-web-sm==2.2.0) (0.1.3)
# Requirement already satisfied: colorama in c:\python\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\python\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (8.1.3)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\python\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python\lib\site-packages (from jinja2->spacy>=2.2.0->en-core-web-sm==2.2.0) (2.1.2)
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
def extract_information(text, keywords):
    preprocessed_text = preprocess_text(text)
    information = {}

    for keyword in keywords:
        if keyword in preprocessed_text:
            # You can extract information related to the keyword here
            # For example, you can extract sentences containing the keyword
            sentences_containing_keyword = [sent.text for sent in nlp(text).sents if keyword in preprocess_text(sent.text)]
            information[keyword] = sentences_containing_keyword

    return information

# %%
keywords = ["company","experience","officer","gmail"]
information = extract_information(text, keywords)

for keyword, sentences in information.items():
#     print(f"Keyword: {keyword}")
    
    for sentence in sentences:
        sentence
    print( )
    
    data_dict = {keyword: sentence}
    json_data = json.dumps(data_dict)
    json_object = json.loads(json_data)
    file_path = 'output.json'
    try:
        with open(file_path, 'r') as file:
            existing_data = json.load(file)
            
    except FileNotFoundError:
        existing_data = {}
    existing_data.update(json_object)

    with open(file_path, 'w') as file:
        json.dump(existing_data, file, indent=2)
    print(json_object)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Python Learning\Python Learning\Current Python learning\image content recognizer\model\Untitled.ipynb Cell 11 line 2
#       <a href='vscode-notebook-cell:/c%3A/Python%20Learning/Python%20Learning/Current%20Python%20learning/image%20content%20recognizer/model/Untitled.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> keywords = ["company","experience","officer","gmail"]
# ----> <a href='vscode-notebook-cell:/c%3A/Python%20Learning/Python%20Learning/Current%20Python%20learning/image%20content%20recognizer/model/Untitled.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> information = extract_information(text, keywords)
#       <a href='vscode-notebook-cell:/c%3A/Python%20Learning/Python%20Learning/Current%20Python%20learning/image%20content%20recognizer/model/Untitled.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> for keyword, sentences in information.items():
#       <a href='vscode-notebook-cell:/c%3A/Python%20Learning/Python%20Learning/Current%20Python%20learning/image%20content%20recognizer/model/Untitled.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> #     print(f"Keyword: {keyword}")
#       <a href='vscode-notebook-cell:/c%3A/Python%20Learning/Python%20Learning/Current%20Python%20learning/image%20content%20recognizer/model/Untitled.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a>     for sentence in sentences:
#
# c:\Python Learning\Python Learning\Current Python learning\image content recognizer\model\Untitled.ipynb Cell 11 line 2
#       <a href='vscode-notebook-cell:/c%3A/Python%20Learning/Python%20Learning/Current%20Python%20learning/image%20content%20recognizer/model/Untitled.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> def extract_information(text, keywords):
# ----> <a href='vscode-notebook-cell:/c%3A/Python%20Learning/Python%20Learning/Current%20Python%20learning/image%20content%20recognizer/model/Untitled.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a>     preprocessed_text = preprocess_text(text)
#       <a href='vscode-notebook-cell:/c%3A/Python%20Learning/Python%20Learning/Current%20Python%20learning/image%20content%20recognizer/model/Untitled.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a>     information = {}
#       <a href='vscode-notebook-cell:/c%3A/Python%20Learning/Python%20Learning/Current%20Python%20learning/image%20content%20recognizer/model/Untitled.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a>     for keyword in keywords:
#
# NameError: name 'preprocess_text' is not defined

# %% [markdown]
# # info extraction
